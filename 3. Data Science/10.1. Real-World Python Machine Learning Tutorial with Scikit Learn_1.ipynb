# %% [markdown]
# # Real-World Python Machine Learning Tutorial w/ Scikit Learn

# %%
# import necessary libraries

import pandas as pd 
from sklearn.model_selection import train_test_split

# %%
df = pd.read_json("D:\\Data Science\\Dataset\\Books_small_10000.json", lines=True)
df.head()
# Out:
#        reviewerID        asin                     reviewerName helpful  \
# 0  A1F2H80A1ZNN1N  B00GDM3NQC                   Connie Correll  [0, 0]
# 1   AI3DRTKCSK4KX  B00A5MREAM                          Grandma  [0, 0]
# 2  A3KAKFHY9DAC8A  0446547573  toobusyreading "Inspired Kathy"  [1, 1]
# 3   ATYBCYD6BIXVL  0955809215                         Chrissie  [0, 0]
# 4  A17K95SEU3J68U  0991500776                Sirde "artist761"  [0, 0]
#
#                                           reviewText  overall  \
# 0  I bought both boxed sets, books 1-5.  Really a...        5
# 1  I enjoyed this short book. But it was way way ...        3
# 2  I love Nicholas Sparks. I&#8217;ve read everyt...        4
# 3  I really enjoyed this adventure and look forwa...        4
# 4  It was a decent read.. typical story line. Not...        3
#
#                                          summary  unixReviewTime   reviewTime
# 0                            Can't stop reading!      1390435200  01 23, 2014
# ...

# %%
new_df =df[["reviewText","overall"]]
new_df.head()
# Out:
#                                           reviewText  overall
# 0  I bought both boxed sets, books 1-5.  Really a...        5
# 1  I enjoyed this short book. But it was way way ...        3
# 2  I love Nicholas Sparks. I&#8217;ve read everyt...        4
# 3  I really enjoyed this adventure and look forwa...        4
# 4  It was a decent read.. typical story line. Not...        3

# %%
new_df["overall"].isnull().sum()
# Out:
# 0

# %%
X = new_df.copy().drop(new_df["overall"])
y =new_df["overall"]

print(X.shape)
print(y.shape)

X_train, y_train, X_test, y_test = train_test_split(X,y, test_size= 0.33, random_state = 42)
# Out:
# (9995, 2)
# (10000,)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-75-46ea718be69f> in <module>()
#       5 print(y.shape)
#       6
# ----> 7 X_train, y_train, X_test, y_test = train_test_split(X,y, test_size= 0.33, random_state = 42)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\model_selection\_split.py in train_test_split(*arrays, **options)
#    2094         raise TypeError("Invalid parameters passed: %s" % str(options))
#    2095
# -> 2096     arrays = indexable(*arrays)
#    2097
#    2098     n_samples = _num_samples(arrays[0])
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py in indexable(*iterables)
#     228         else:
#     229             result.append(np.array(X))
# --> 230     check_consistent_length(*result)
#     231     return result
#     232
#
# ...

# %%
y.shape
# Out:
# (10000,)

# %%
new_df.tail(50)
# Out:
#                                              reviewText  overall
# 9950  This one is written very well, but it's still ...        4
# 9951  I am still using this book and will go back to...        5
# 9952  This is marketed as a vampire book, and I do h...        4
# 9953  Anyone who may have a remote interest in the p...        5
# 9954  Like most schools boys, I had heard of the Gre...        5
# 9955  I learned a lot about Italy's history. History...        5
# 9956  keeps it alive and replaceable. I was surprise...        5
# 9957  We know carbs are bad for us, especially white...        5
# 9958  This is a series of three childhood friends an...        4
# 9959  There are six short stories in this novel.  Si...        5
# 9960  GREAT SERIES!!  Do not hesitate on this series...        5
# 9961  Echo, Echo, Echo.... You beautiful, cocky, swe...        5
# 9962  Been waiting impatiently for this book to come...        4
# ...

# %%
class Sentiment:
    NEGATIVE = 'NEGATIVE'
    NEUTRAL = 'NEUTRAL'
    POSITIVE = 'POSITIVE'

class Review:
    def __init__(self, text , score):
        self.text = text
        self.score = score
        self.sentiment = self.get_sentiment()
        
    def get_sentiment(self):
        if self.score <= 2:
            return Sentiment.NEGATIVE
        elif self.score == 3:
            return Sentiment.NEUTRAL
        else:
            return Sentiment.POSITIVE
